# %% [markdown]
# 수치형 데이터를 가지고 간단한 모델을 만들어 봅시다
#
# https://www.kaggle.com/datasets/altavish/boston-housing-dataset
#
# kaggle에서 여러 데이터셋을 얻을 수 있습니다. 가입이 필요합니다

# %% [markdown]
# 다운로드한 파일을 구글 드라이브에 업로드합니다

# %%
import pandas as pd  # csv 파일을 읽기 위해서 pandas 라이브러리를 불러옵니다

# %% [markdown]
# 구글 드라이브 마운트 후에 데이터를 불러옵니다

# %%
df = pd.read_csv('/content/drive/MyDrive/Teaching/PD 2401/HousingData.csv')

# %%
df.head(20)
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 0   0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900    1  296
# 1   0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671    2  242
# 2   0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671    2  242
# 3   0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622    3  222
# 4   0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622    3  222
# 5   0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    3  222
# 6   0.08829  12.5   7.87   NaN  0.524  6.012   66.6  5.5605    5  311
# 7   0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    5  311
# 8   0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311
# 9   0.17004  12.5   7.87   NaN  0.524  6.004   85.9  6.5921    5  311
# 10  0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467    5  311
# 11  0.11747  12.5   7.87   0.0  0.524  6.009   82.9  6.2267    5  311
# 12  0.09378  12.5   7.87   0.0  0.524  5.889   39.0  5.4509    5  311
# 13  0.62976   0.0   8.14   0.0  0.538  5.949   61.8  4.7075    4  307
# 14  0.63796   0.0   8.14   NaN  0.538  6.096   84.5  4.4619    4  307
# 15  0.62739   0.0   8.14   0.0  0.538  5.834   56.5  4.4986    4  307
# 16  1.05393   0.0   8.14   0.0  0.538  5.935   29.3  4.4986    4  307
# 17  0.78420   0.0   8.14   0.0  0.538  5.990   81.7  4.2579    4  307
# 18  0.80271   0.0   8.14   0.0  0.538  5.456   36.6  3.7965    4  307
# 19  0.72580   0.0   8.14   0.0  0.538  5.727   69.5  3.7965    4  307
#
#     PTRATIO       B  LSTAT  MEDV
# 0      15.3  396.90   4.98  24.0
# 1      17.8  396.90   9.14  21.6
# 2      17.8  392.83   4.03  34.7
# 3      18.7  394.63   2.94  33.4
# 4      18.7  396.90    NaN  36.2
# 5      18.7  394.12   5.21  28.7
# 6      15.2  395.60  12.43  22.9
# 7      15.2  396.90  19.15  27.1
# 8      15.2  386.63  29.93  16.5
# 9      15.2  386.71  17.10  18.9
# 10     15.2  392.52  20.45  15.0
# 11     15.2  396.90  13.27  18.9
# 12     15.2  390.50  15.71  21.7
# 13     21.0  396.90   8.26  20.4
# 14     21.0  380.02  10.26  18.2
# 15     21.0  395.62   8.47  19.9
# 16     21.0  386.85   6.58  23.1
# 17     21.0  386.75  14.67  17.5
# 18     21.0  288.99  11.69  20.2
# 19     21.0  390.95  11.28  18.2

# %%
len(df)
# Out:
# 506

# %%
# 수치값이 맞게 들어왔는지 확인합니다

df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df = df.dropna()  # 빈데이터가 있는 행을 삭제

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  394.000000  394.000000  394.000000  394.000000  394.000000  394.000000
# mean     3.690136   11.460660   11.000863    0.068528    0.553215    6.280015
# std      9.202423   23.954082    6.908364    0.252971    0.113112    0.697985
# min      0.006320    0.000000    0.460000    0.000000    0.389000    3.561000
# 25%      0.081955    0.000000    5.130000    0.000000    0.453000    5.879250
# 50%      0.268880    0.000000    8.560000    0.000000    0.538000    6.201500
# 75%      3.435973   12.500000   18.100000    0.000000    0.624000    6.605500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  394.000000  394.000000  394.000000  394.000000  394.000000  394.000000
# mean    68.932741    3.805268    9.403553  406.431472   18.537563  358.490939
# std     27.888705    2.098571    8.633451  168.312419    2.166460   89.283295
# min      2.900000    1.129600    1.000000  187.000000   12.600000    2.600000
# 25%     45.475000    2.110100    4.000000  280.250000   17.400000  376.707500
# 50%     77.700000    3.199200    5.000000  330.000000   19.100000  392.190000
# 75%     94.250000    5.116700   24.000000  666.000000   20.200000  396.900000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  394.000000  394.000000
# mean    12.769112   22.359645
# std      7.308430    9.142979
# min      1.730000    5.000000
# 25%      7.125000   16.800000
# 50%     11.300000   21.050000
# 75%     17.117500   25.000000
# max     37.970000   50.000000

# %% [markdown]
# x,y를 나눕니다. (feature와 target을 분리)

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 5  394.12   5.21

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 5      28.7
#        ...
# 499    17.5
# 500    16.8
# 502    20.6
# 503    23.9
# 504    22.0
# Name: MEDV, Length: 394, dtype: float64

# %%
x = x.values # numpy 배열만 가져옴

# %%
y = y.values

# %%
type(x)
# Out:
# numpy.ndarray

# %%
type(y)
# Out:
# numpy.ndarray

# %%
x.shape
# Out:
# (394, 13)

# %% [markdown]
# 데이터를 tensor로 변경합시다
# 이때 float32로 타입을 변경합니다.
#
# torch에서 모델 만들때 파라미터 데이터 타입이 기본적으로 float32를 사용하기 때문에 지정 안할 시 float64로 변환되면 오류 발생합니다

# %%
import torch
from torch import nn

# %%
x = torch.from_numpy(x).float()
y = torch.from_numpy(y).float()

# %%
# x = torch.tensor(x, dtype=torch.float32)
# y = torch.tensor(y, dtype=torch.float32)

# %%
x.shape
# Out:
# torch.Size([394, 13])

# %%
y.shape
# Out:
# torch.Size([394])

# %%
x.dtype
# Out:
# torch.float32

# %%
y.dtype
# Out:
# torch.float32

# %% [markdown]
# 2개의 레이어로 이루어진 모델을 만들어보겠습니다.
#
# nn.Sequential()을 활용해서 구성해보겠습니다.
#
# 13개의 Input이 있고, 최종적으로 1개의 output이 있습니다.

# %%
model = nn.Sequential(
    nn.Linear(13, 64),
    nn.ReLU(),
    nn.Linear(64, 1)
)

# %%
model
# Out:
# Sequential(
#   (0): Linear(in_features=13, out_features=64, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
# 모델 파라미터의 데이터 타입 확인 코드입니다

for name, param in model.named_parameters():
    print(name, param.dtype)
# Out:
# 0.weight torch.float32
# 0.bias torch.float32
# 2.weight torch.float32
# 2.bias torch.float32

# %%
model(x[:10]) # 모델이 작동하는지 확인해봅니다
# Out:
# tensor([[-14.2115],
#         [-16.3920],
#         [-14.9117],
#         [-13.8482],
#         [-14.6031],
#         [-16.2800],
#         [-15.7677],
#         [-15.8728],
#         [-15.2867],
#         [-11.7147]], grad_fn=<AddmmBackward0>)

# %%
model(x[:10]).shape  #모델의 output은 2차원으로 나옴
# Out:
# torch.Size([10, 1])

# %% [markdown]
# loss function과 optimizer를 지정합니다.

# %%
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# 모델 학습을 해봅시다.
# 이때 데이터셋을 batch 단위로 나누어서 학습을 해보겠습니다.

# %%
epochs = 1000
batch_size = 10

# %%
for epoch in range(epochs):
  running_loss = 0 # 전체 데이터셋에 대한 loss 계산

  # 데이터를 batch로 나누어서 학습
  for i in range(0, x.shape[0], batch_size): #range(start, end, step), end는 미포함
    inputs = x[i:i+batch_size,:]
    labels = y[i:i+batch_size]

    optimizer.zero_grad() # gradient 초기화
    outputs = model(inputs) # 모델값 예측
    #print(outputs)
    loss = loss_fn(outputs, labels.unsqueeze(dim=1)) # 에러 계산, unsqueeze(): 모델의 output과 원래 데이터 shape 맞추기
    loss.backward() # gradient 계산
    optimizer.step() # gradient 업데이트

    running_loss += loss.item() * batch_size

  if (epoch+1)%10==0:
    print('Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, epochs, running_loss / x.shape[0]))
# Out:
# Epoch [10/1000], Loss: 71.9824
# Epoch [20/1000], Loss: 65.1182
# Epoch [30/1000], Loss: 57.3883
# Epoch [40/1000], Loss: 53.7154
# Epoch [50/1000], Loss: 50.3515
# Epoch [60/1000], Loss: 48.2993
# Epoch [70/1000], Loss: 43.9873
# Epoch [80/1000], Loss: 42.9450
# Epoch [90/1000], Loss: 40.9147
# Epoch [100/1000], Loss: 40.5360
# Epoch [110/1000], Loss: 36.9124
# Epoch [120/1000], Loss: 35.1183
# Epoch [130/1000], Loss: 33.0823
# Epoch [140/1000], Loss: 31.8010
# Epoch [150/1000], Loss: 30.1540
# Epoch [160/1000], Loss: 29.9309
# Epoch [170/1000], Loss: 28.2790
# Epoch [180/1000], Loss: 26.8323
# Epoch [190/1000], Loss: 25.4964
# Epoch [200/1000], Loss: 24.4947
# Epoch [210/1000], Loss: 25.6964
# Epoch [220/1000], Loss: 23.5268
# Epoch [230/1000], Loss: 22.0548
# Epoch [240/1000], Loss: 21.8193
# Epoch [250/1000], Loss: 20.9295
# Epoch [260/1000], Loss: 20.1307
# Epoch [270/1000], Loss: 19.9542
# Epoch [280/1000], Loss: 19.6311
# Epoch [290/1000], Loss: 18.9494
# Epoch [300/1000], Loss: 19.0625
# Epoch [310/1000], Loss: 19.0485
# Epoch [320/1000], Loss: 18.8521
# Epoch [330/1000], Loss: 17.6345
# Epoch [340/1000], Loss: 17.1309
# Epoch [350/1000], Loss: 17.1439
# Epoch [360/1000], Loss: 17.1733
# Epoch [370/1000], Loss: 16.3167
# Epoch [380/1000], Loss: 15.4337
# Epoch [390/1000], Loss: 14.9289
# Epoch [400/1000], Loss: 14.9729
# Epoch [410/1000], Loss: 15.0469
# Epoch [420/1000], Loss: 14.9909
# Epoch [430/1000], Loss: 15.7763
# Epoch [440/1000], Loss: 15.7789
# Epoch [450/1000], Loss: 14.9638
# Epoch [460/1000], Loss: 14.5253
# Epoch [470/1000], Loss: 13.3723
# Epoch [480/1000], Loss: 13.4146
# Epoch [490/1000], Loss: 14.1777
# Epoch [500/1000], Loss: 12.9669
# Epoch [510/1000], Loss: 13.5787
# Epoch [520/1000], Loss: 12.8392
# Epoch [530/1000], Loss: 13.2882
# Epoch [540/1000], Loss: 12.3370
# Epoch [550/1000], Loss: 12.5230
# Epoch [560/1000], Loss: 12.4774
# Epoch [570/1000], Loss: 12.3479
# Epoch [580/1000], Loss: 12.2991
# Epoch [590/1000], Loss: 12.1723
# Epoch [600/1000], Loss: 12.1378
# Epoch [610/1000], Loss: 11.6789
# Epoch [620/1000], Loss: 11.7071
# Epoch [630/1000], Loss: 11.8380
# Epoch [640/1000], Loss: 14.6788
# Epoch [650/1000], Loss: 19.6411
# Epoch [660/1000], Loss: 15.2273
# Epoch [670/1000], Loss: 12.2018
# Epoch [680/1000], Loss: 11.7620
# Epoch [690/1000], Loss: 11.5668
# Epoch [700/1000], Loss: 11.3104
# Epoch [710/1000], Loss: 10.9903
# Epoch [720/1000], Loss: 11.2315
# Epoch [730/1000], Loss: 11.0073
# Epoch [740/1000], Loss: 11.6454
# Epoch [750/1000], Loss: 11.5374
# Epoch [760/1000], Loss: 10.4493
# Epoch [770/1000], Loss: 12.0818
# Epoch [780/1000], Loss: 16.1764
# Epoch [790/1000], Loss: 10.2914
# Epoch [800/1000], Loss: 10.1848
# Epoch [810/1000], Loss: 9.7721
# Epoch [820/1000], Loss: 9.6936
# Epoch [830/1000], Loss: 10.8568
# Epoch [840/1000], Loss: 10.9237
# Epoch [850/1000], Loss: 10.6737
# Epoch [860/1000], Loss: 10.2716
# Epoch [870/1000], Loss: 11.5955
# Epoch [880/1000], Loss: 9.6298
# Epoch [890/1000], Loss: 9.8145
# Epoch [900/1000], Loss: 9.5383
# Epoch [910/1000], Loss: 10.7715
# Epoch [920/1000], Loss: 12.6407
# Epoch [930/1000], Loss: 9.6757
# Epoch [940/1000], Loss: 9.7957
# Epoch [950/1000], Loss: 10.4684
# Epoch [960/1000], Loss: 9.6141
# Epoch [970/1000], Loss: 9.7233
# Epoch [980/1000], Loss: 10.0300
# Epoch [990/1000], Loss: 9.9275
# Epoch [1000/1000], Loss: 9.8328

# %%
for name, param in model.named_parameters():
    print(name, param.shape)
# Out:
# 0.weight torch.Size([64, 13])
# 0.bias torch.Size([64])
# 2.weight torch.Size([1, 64])
# 2.bias torch.Size([1])

# %%
y_pred = model(x)

# %%
y_pred.shape
# Out:
# torch.Size([394, 1])

# %%
y_pred = y_pred.squeeze()

# %%
y_pred.shape
# Out:
# torch.Size([394])

# %%
y.shape
# Out:
# torch.Size([394])

# %%
import matplotlib.pyplot as plt

plt.scatter(y_pred.detach().numpy(), y.detach().numpy())
